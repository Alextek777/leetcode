# %% [markdown]
# [1161. Maximum Level Sum of a Binary Tree](https://leetcode.com/problems/maximum-level-sum-of-a-binary-tree/description/?envType=daily-question&envId=2026-01-06)
#
# BFS

# %%
from typing import Optional
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def maxLevelSum(self, root: Optional[TreeNode]) -> int:
        maxLVL = 1
        maxNum = root.val

        curNum = 0
        curLVL = 1
        nonNilValuesPerLvl = 0

        queue = deque([root])
        nextQueue = deque()

        while queue:
            node = queue.popleft()
            if node != None:
                nextQueue.append(node.left)
                nextQueue.append(node.right)

                curNum += node.val
                nonNilValuesPerLvl += 1

            if len(queue) == 0:
                if curNum > maxNum and nonNilValuesPerLvl > 0:
                    maxLVL = curLVL
                    maxNum = curNum

                curLVL += 1
                curNum = 0
                nonNilValuesPerLvl = 0
                queue = nextQueue.copy()
                nextQueue.clear()


        return maxLVL

# %%
s = Solution()

root1 = TreeNode(
    left=TreeNode(
        left=TreeNode(
            val=7
        ),

        right=TreeNode(
            val = -8
        ),

        val=7
    ),

    right=TreeNode(
        val=0
    ),

    val=1
)

s.maxLevelSum(root1)
# Out:
# 2

# %%
root2 = TreeNode(
    left=TreeNode(
        left=TreeNode(
            val=-20
        ),

        right=TreeNode(
            val = -5
        ),

        val=-200
    ),

    right=TreeNode(
        left=TreeNode(
            val=-10
        ),
        val=-300
    ),

    val=-100
)

s.maxLevelSum(root2)
# Out:
# 3

# %% [markdown]
# ### without nextQueue.copy()

# %%
class Solution2:
    def maxLevelSum(self, root: Optional[TreeNode]) -> int:
        curr_lvl = 1
        maxi = float('-inf')
        ans = 1

        queue = deque([root])

        while queue:
            curr_sum = 0
            lvl_size = len(queue)

            for _ in range(lvl_size):
                node = queue.popleft()
                curr_sum += node.val

                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            
            if curr_sum > maxi:
                maxi = curr_sum
                ans = curr_lvl

            curr_lvl += 1
        
        return ans

# %%
s2 = Solution2()

# %%
s2.maxLevelSum(root1)
# Out:
# 2

# %%
s2.maxLevelSum(root2)
# Out:
# 3
